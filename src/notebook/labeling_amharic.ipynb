# %%
# ------------------------
# SETUP AND IMPORTS
# ------------------------
import pandas as pd
import re

# Load the dataset
df = pd.read_csv("../../data/telegram_data.csv")
messages = df["text"].dropna().tolist()[:50]

# %%
def tokenize_amharic(text):
    # Tokenize Amharic and numbers, fallback to whitespace for other tokens
    tokens = re.findall(r'[\u1200-\u137F]+|\d+|[^\s\u1200-\u137F]+', str(text))
    return tokens

# %%
# Manually label entities in the messages
# Entity labels: B-Product, I-Product, B-LOC, I-LOC


entity_labels = ["B-Product", "I-Product", "B-LOC", "I-LOC", "B-PRICE", "I-PRICE", "O"]
labeled_sentences = []

for idx, msg in enumerate(messages):
    print(f"\nMessage {idx+1}: {msg}")
    tokens = tokenize_amharic(msg)
    labels = []
    for token in tokens:
        print(f"Token: {token}")
        label = input(f"Label for '{token}' ({'/'.join(entity_labels)}): ")
        if label not in entity_labels:
            label = "O"
        labels.append((token, label))
    labeled_sentences.append(labels)
# Out:
# Message 1: Skechers Ultra Lace
# Size 40,41,43
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Ultra
# Token: Lace
# Token: Size
# Token: 40
# Token: ,41,43
# Token: Price
# Token: 3400
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 2: ‼️ እሁድ ሁሌም ክፍት ነን ‼️
#
# Reebok Club Vintage
# size 40,41,42,43
# Price 3300 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: ‼️
# Token: እሁድ
# Token: ሁሌም
# Token: ክፍት
# Token: ነን
# Token: ‼️
# Token: Reebok
# Token: Club
# Token: Vintage
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3300
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 3: Skechers archfit
# size 40,41,42,43
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: archfit
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3400
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 4: ‼️ እሁድ ሁሌም ክፍት ነን ‼️
#
# NB 04 leather
# Size 39,40,41,42,43,44
# Price 4500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: ‼️
# Token: እሁድ
# Token: ሁሌም
# Token: ክፍት
# Token: ነን
# Token: ‼️
# Token: NB
# Token: 04
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 5: Nike Air Force Paisley
# Size 40,41,42,43,44
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Nike
# Token: Air
# Token: Force
# Token: Paisley
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 6: Skechers GY ULTRA
# Size 40,41,42,43,44
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: GY
# Token: ULTRA
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3400
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 7: Adidas Samba OG
# size 40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Adidas
# Token: Samba
# Token: OG
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 8: Colombia vibram
# Size 40,41,42,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Colombia
# Token: vibram
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 9: Skechers Delux Walker
# Size 40,41,42,43
# Price 3800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Delux
# Token: Walker
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3800
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 10: Alta buckle leather
# Size 39,40,41,42,43,44
# Price 4500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Alta
# Token: buckle
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 11: Skechers Ultra Lace
# Size 40,41,42,43,44
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Ultra
# Token: Lace
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3400
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 12: Adidas bad bunny campus
# Size 40,41,42,43,44
# Price 3800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Adidas
# Token: bad
# Token: bunny
# Token: campus
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3800
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 13: Waerta loafer leather
# Size 39,40,41,42,43,44
# Price 4500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                      [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Waerta
# Token: loafer
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 14: Air Jordan Stay Loyal
# Size 40,41,42,43,44
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Air
# Token: Jordan
# Token: Stay
# Token: Loyal
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3400
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 15: ‼️ እሁድ ሁሌም ክፍት ነን ‼️
#
# Skechers Flex Groove
# size 40,41,42,43
# Price 3800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: ‼️
# Token: እሁድ
# Token: ሁሌም
# Token: ክፍት
# Token: ነን
# Token: ‼️
# Token: Skechers
# Token: Flex
# Token: Groove
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3800
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 16: Colombia Hiking
# Size 40,41,42,43,44
# Price 3900 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Colombia
# Token: Hiking
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3900
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 17: Nike Air Force the north face
# Size 40,41,42,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Nike
# Token: Air
# Token: Force
# Token: the
# Token: north
# Token: face
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 18: NB 04 leather
# Size 39,40,41,42,43,44
# Price 4500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: NB
# Token: 04
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 19: Air Jordan 9
# Size 40,41,42,43,44
# Price 3800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Air
# Token: Jordan
# Token: 9
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3800
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 20: 🆕 New Stocks (አዲስ የገባ) 🆕
#
# - እነዚህ እና የተለያዩ አዲስ ጫማዎችን በዛሬው እለት አስገብተናል፡፡
# መተው ይጎብኙን፡፡
#
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: 🆕
# Token: New
# Token: Stocks
# Token: (
# Token: አዲስ
# Token: የገባ
# Token: )
# Token: 🆕
# Token: -
# Token: እነዚህ
# Token: እና
# Token: የተለያዩ
# Token: አዲስ
# Token: ጫማዎችን
# Token: በዛሬው
# Token: እለት
# Token: አስገብተናል፡፡
# Token: መተው
# Token: ይጎብኙን፡፡
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 21: Alta buckle leather
# Size 39,40,41,42,43,44
# Price 4500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Alta
# Token: buckle
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 22: Skechers Delux Walker
# Size 40,41,42,43
# Price 3800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Delux
# Token: Walker
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3800
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 23: ‼️ እሁድ ሁሌም ክፍት ነን ‼️
#
# Adidas terrex Running
# size 40,41,42
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: ‼️
# Token: እሁድ
# Token: ሁሌም
# Token: ክፍት
# Token: ነን
# Token: ‼️
# Token: Adidas
# Token: terrex
# Token: Running
# Token: size
# Token: 40
# Token: ,41,42
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 24: Converse all star leather high
# Size 40,41,42,43
# Price 3200 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Converse
# Token: all
# Token: star
# Token: leather
# Token: high
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3200
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 25: Nike LeBron Witness
# size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Nike
# Token: LeBron
# Token: Witness
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 26: Adidas cloud foam new
# Size 40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Adidas
# Token: cloud
# Token: foam
# Token: new
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 27: Colombia Montrial
# size 40,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Colombia
# Token: Montrial
# Token: size
# Token: 40
# Token: ,43
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 28: Skechers Out door taupe
# Size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Out
# Token: door
# Token: taupe
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 29: ‼️ እሁድ ሁሌም ክፍት ነን ‼️
#
# Nike infinity flow
# size 40,41,42,43,44
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: ‼️
# Token: እሁድ
# Token: ሁሌም
# Token: ክፍት
# Token: ነን
# Token: ‼️
# Token: Nike
# Token: infinity
# Token: flow
# Token: size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 30: Piclse loafers leather
# Size 39,40,41,42,43,44
# Price 4200 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Piclse
# Token: loafers
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4200
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 31: Skechers Quantum flex
# size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Quantum
# Token: flex
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 32: Nike LeBron Witness
# size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Nike
# Token: LeBron
# Token: Witness
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 33: Under Armour Maven Trek
# size 40,41,42,43
# Price 4000 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Under
# Token: Armour
# Token: Maven
# Token: Trek
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 4000
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 34: Piclse loafers leather
# Size 39,40,41,42,43,44
# Price 4200 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Piclse
# Token: loafers
# Token: leather
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4200
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 35: Skechers Out door taupe
# Size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Out
# Token: door
# Token: taupe
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 36: Nike infinity flow
# size 40,41,42,43,44
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Nike
# Token: infinity
# Token: flow
# Token: size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 37: Skechers Quantum flex
# size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Skechers
# Token: Quantum
# Token: flex
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 38: Colombia Montrial
# size 40,41,42,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Colombia
# Token: Montrial
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 39: Nike i free run
# Size 40,41,42,43
# Price 3500 birr
# 🏢አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
# Token: Nike
# Token: i
# Token: free
# Token: run
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3500
# Token: birr
# Token: 🏢
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
#
# Message 40: Puma beige SD
# Size 40,41,42,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Puma
# Token: beige
# Token: SD
# Token: Size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 41: Adidas cloud foam new
# Size 40,41,42,43,44
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Adidas
# Token: cloud
# Token: foam
# Token: new
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 42: Manladuo suede Chelsea boots
# size 40,41,42,43
# Price 5400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Manladuo
# Token: suede
# Token: Chelsea
# Token: boots
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 5400
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 43: Adidas terrex Running
# size 40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Adidas
# Token: terrex
# Token: Running
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 44: Pristine loafer leather
# size 39,40,41,42,43,44
# Price 4800 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Pristine
# Token: loafer
# Token: leather
# Token: size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4800
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 45: Nike LeBron Witness
# size 40,41,42,43,44
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Nike
# Token: LeBron
# Token: Witness
# Token: size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3500
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 46: Colombia Montrial
# size 40,41,42,43
# Price 3700 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Colombia
# Token: Montrial
# Token: size
# Token: 40
# Token: ,41,42,43
# Token: Price
# Token: 3700
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 47: Under Armour Maven Trek
# size 40,41,42,43,44,45
# Price 4000 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Under
# Token: Armour
# Token: Maven
# Token: Trek
# Token: size
# Token: 40
# Token: ,41,42,43,44,45
# Token: Price
# Token: 4000
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 48: NB pure leather comfort
# Size 39,40,41,42,43,44
# Price 4200 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                      [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: NB
# Token: pure
# Token: leather
# Token: comfort
# Token: Size
# Token: 39
# Token: ,40,41,42,43,44
# Token: Price
# Token: 4200
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 49: Reebok Winterized
# Size 40,41,42,43,44
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Reebok
# Token: Winterized
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅
#
# Message 50: Adidas cloud foam new
# Size 40,41,42,43,44
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     [EthioBrand](https://t.me/ethio_brand_collection) ✅
# Token: Adidas
# Token: cloud
# Token: foam
# Token: new
# Token: Size
# Token: 40
# Token: ,41,42,43,44
# Token: Price
# Token: 3600
# Token: birr
# Token: 📌
# Token: አድራሻ
# Token: -
# Token: ሜክሲኮ
# Token: ኮሜርስ
# Token: ጀርባ
# Token: መዚድ
# Token: ፕላዛ
# Token: የመጀመሪያ
# Token: ደረጃ
# Token: እንደወጡ
# Token: 101
# Token: የቢሮ
# Token: ቁጥር
# Token: ያገኙናል
# Token: or
# Token: call
# Token: 0920238243
# Token: [EthioBrand](https://t.me/ethio_brand_collection)
# Token: ✅

# %%
#Save labeled data to a file 
with open("../../data/labeled_amharic.conll", "w", encoding="utf-8") as f:
    for sentence in labeled_sentences:
        for token, label in sentence:
            f.write(f"{token} {label}\n")
        f.write("\n")  # Sentence separator
print("Saved labeled data to ../../data/labeled_amharic.conll")
# Out:
# Saved labeled data to ../../data/labeled_amharic.conll
